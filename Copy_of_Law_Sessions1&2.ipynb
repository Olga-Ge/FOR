# %% [markdown]
# <a href="https://colab.research.google.com/github/Olga-Ge/FOR/blob/master/Copy_of_Law_Sessions1%262.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://raw.githubusercontent.com/itb-ie/MasterLaw-Session1-2/master/Title.png'>
#
# <img src='https://datawider.com/wp-content/uploads/2019/11/How-to-Learn-Python.jpg' width=500px />
#
# <img src='https://pprablog.files.wordpress.com/2015/03/gravel.jpg' width=330px />
#
# <br><br>
# # <center>Sessions 1&2 </center>
#
# ## Welcome back!<br>
#
# Here are the things we will do in these sessions:
#
# 1.   Introduction to Google Colab
# 2.   Regular Expressions + Examples
# 3.   Graphical User Interface
# 4.   Create Applications with Graphical User Interfaces
# 5.   Bundle the Application into an Executable and Run without Python
#
# ## Evaluation Method
#
# | Criteria | Score |
# ---|---
# | Class Participation | 30% |
# | Forums | 40% |
# | Final Exam | 30 % |
#
# <br><br>

# %% [markdown]
# # <center>Google Colab</center>
#
# <p><img alt="Colaboratory logo" height="45px" src="/img/colab_favicon.ico" align="left" hspace="10px" vspace="0px"></p>
#
# <h1>What is Colaboratory?</h1>
#
# Colaboratory, or "Colab" for short, allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Free access to GPUs
# - Easy sharing
#
# Whether you're a **student**, a **data scientist** or an **AI researcher**, Colab can make your work easier. Watch [Introduction to Colab](https://www.youtube.com/watch?v=inN8seMm7UI) to learn more, or just get started below!
# (Google's presentation of their platform)
#
# This is a google colab page. As you can see it can be formated quite nicely. The most important part is that you can introduce coding inside this page (python for now). Here is a block of python code:

# %%
# I am now writing python code:
a = 10
b = 6
print("The result is", a+b)
# to run this code you just need to press the play button
# Out:
# The result is 16

# %% [markdown]
# ## Cells
# A document in Colab is called a notebook. The name and original purpose was to design a tool that replaces the "notebook" in which an engineer or scientist takes notes. But it has become a very useful tool for online teaching of programming. <br>
# The notebook is a list of cells. Cells contain either explanatory text or executable code and its output. Click a cell to select it.

# %% [markdown]
# **bold text**## Text Cells
#
# This is a text cell. As you can see it contains all sorts of text, like this one.
# Formatting the text is based on the Markdown language (same that we have used in github to create the readme files).
# You can have *italic* **bold** ~~strikethrough~~ or any _**~~combination~~**_
# <br>
# ___
#
# You can create lists:
# - apple
# - *orange is special*
# - some other generic fruit
#
# Numbered list:
# 1. Item1
# 2. Item2
# 3. Item3
#
# Or tasks list:
# - [x] Enroll in IE
# - [ ] Learn Python from Bogdan
# - [ ] Get rich
#
# You can add links:
# [Our (*actually my) github page](https://github.com/itb-ie)
# <br><br><br>
# And you can add images: <br>
# ![alt text](https://memegenerator.net/img/instances/68550956/i-should-learn-python-functional-programming.jpg)
#
# Or we can create a table:<br>
#
# |*Hour* | Monday | Tuesday | Wednesday |Saturday |
# |-------|--------|---------|-----------|---------|
# |9-13 | Work   | Work    | Work      | Chill   |
# |13-14| Lunch   | Lunch    | Lunch      | Brunch   |
# |14-19| Work   | Work    | Work      | Go outside   |
# |19-23|Relax\*  |Relax\* |Relax\* |Relax\* |
# |23-07|Sleep|Sleep|Sleep|**Party\***|
# <sub> \*not applicable if you have kids </sub>
#
#
#
#
# ### So as you can see, there is quite a lot of things that you can do with this text editor

# %% [markdown]
# ##Coding Cells

# %%
name = input("What is your name?")
print("Nice to meet you", name)
# Out:
# What is your name?Olga
# Nice to meet you Olga

# %%
# this is another coding part, we get to keep what was in the previous cell
print("the name you have entered previuosly was", name)
# Out:
# the name you have entered previuosly was Olga

# %% [markdown]
# You can add various explanation parts between the coding parts.<br>
# And then continue with the code:

# %%
# this is how you import things (like normal)
from datetime import date
print("Dear", name, "today is:", date.today())
# Out:
# Dear Raluca today is: 2020-06-12

# %% [markdown]
# ## You can draw graphs:

# %%
import numpy as np
import matplotlib.pyplot as plt

title = "I drew this for you, " + name
ox = np.arange(0, 4*np.pi, 0.1)
oy = np.sin(ox)
plt.plot(ox, oy, label="sin(x)")
plt.title(title)
plt.legend()
plt.show()

# %% [markdown]
# ## Or much fancier, sciency things:

# %%
from matplotlib.collections import PolyCollection
import matplotlib.pyplot as plt
from matplotlib import colors as mcolors
import numpy as np

# Fixing random state for reproducibility



def polygon_under_graph(xlist, ylist):
    """
    Construct the vertex list which defines the polygon filling the space under
    the (xlist, ylist) line graph.  Assumes the xs are in ascending order.
    """
    return [(xlist[0], 0.), *zip(xlist, ylist), (xlist[-1], 0.)]


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make verts a list such that verts[i] is a list of (x, y) pairs defining
# polygon i.
verts = []

# Set up the x sequence
xs = np.linspace(0., 10., 26)

# The ith polygon will appear on the plane y = zs[i]
zs = range(4)

for i in zs:
    ys = np.random.rand(len(xs))
    verts.append(polygon_under_graph(xs, ys))

poly = PolyCollection(verts, facecolors=['r', 'g', 'b', 'y'], alpha=.6)
ax.add_collection3d(poly, zs=zs, zdir='y')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_xlim(0, 10)
ax.set_ylim(-1, 4)
ax.set_zlim(0, 1)
plt.title("Are you impressed, {}?".format(name))

plt.show()

# %%
import matplotlib.cm as cm
import matplotlib.pyplot as plt
from matplotlib.patches import Circle, PathPatch
from matplotlib.path import Path
from matplotlib.transforms import Affine2D
import numpy as np

# Fixing random state for reproducibility
np.random.seed(19680801)


r = np.random.rand(50)
t = np.random.rand(50) * np.pi * 2.0
x = r * np.cos(t)
y = r * np.sin(t)

fig, ax = plt.subplots(figsize=(6, 6))
circle = Circle((0, 0), 1, facecolor='none',
                edgecolor=(0, 0.8, 0.8), linewidth=3, alpha=0.5)
ax.add_patch(circle)

im = plt.imshow(np.random.random((100, 100)),
                origin='lower', cmap=cm.winter,
                interpolation='spline36',
                extent=([-1, 1, -1, 1]))
im.set_clip_path(circle)

plt.plot(x, y, 'o', color=(0.9, 0.9, 1.0), alpha=0.8)

# Dolphin from OpenClipart library by Andy Fitzsimon
#       <cc:License rdf:about="http://web.resource.org/cc/PublicDomain">
#         <cc:permits rdf:resource="http://web.resource.org/cc/Reproduction"/>
#         <cc:permits rdf:resource="http://web.resource.org/cc/Distribution"/>
#         <cc:permits rdf:resource="http://web.resource.org/cc/DerivativeWorks"/>
#       </cc:License>

dolphin = """
M -0.59739425,160.18173 C -0.62740401,160.18885 -0.57867129,160.11183
-0.57867129,160.11183 C -0.57867129,160.11183 -0.5438361,159.89315
-0.39514638,159.81496 C -0.24645668,159.73678 -0.18316813,159.71981
-0.18316813,159.71981 C -0.18316813,159.71981 -0.10322971,159.58124
-0.057804323,159.58725 C -0.029723983,159.58913 -0.061841603,159.60356
-0.071265813,159.62815 C -0.080250183,159.65325 -0.082918513,159.70554
-0.061841203,159.71248 C -0.040763903,159.7194 -0.0066711426,159.71091
0.077336307,159.73612 C 0.16879567,159.76377 0.28380306,159.86448
0.31516668,159.91533 C 0.3465303,159.96618 0.5011127,160.1771
0.5011127,160.1771 C 0.63668998,160.19238 0.67763022,160.31259
0.66556395,160.32668 C 0.65339985,160.34212 0.66350443,160.33642
0.64907098,160.33088 C 0.63463742,160.32533 0.61309688,160.297
0.5789627,160.29339 C 0.54348657,160.28968 0.52329693,160.27674
0.50728856,160.27737 C 0.49060916,160.27795 0.48965803,160.31565
0.46114204,160.33673 C 0.43329696,160.35786 0.4570711,160.39871
0.43309565,160.40685 C 0.4105108,160.41442 0.39416631,160.33027
0.3954995,160.2935 C 0.39683269,160.25672 0.43807996,160.21522
0.44567915,160.19734 C 0.45327833,160.17946 0.27946869,159.9424
-0.061852613,159.99845 C -0.083965233,160.0427 -0.26176109,160.06683
-0.26176109,160.06683 C -0.30127962,160.07028 -0.21167141,160.09731
-0.24649368,160.1011 C -0.32642366,160.11569 -0.34521187,160.06895
-0.40622293,160.0819 C -0.467234,160.09485 -0.56738444,160.17461
-0.59739425,160.18173
"""

vertices = []
codes = []
parts = dolphin.split()
i = 0
code_map = {
    'M': (Path.MOVETO, 1),
    'C': (Path.CURVE4, 3),
    'L': (Path.LINETO, 1)}

while i < len(parts):
    code = parts[i]
    path_code, npoints = code_map[code]
    codes.extend([path_code] * npoints)
    vertices.extend([[float(x) for x in y.split(',')] for y in
                     parts[i + 1:i + npoints + 1]])
    i += npoints + 1
vertices = np.array(vertices, float)
vertices[:, 1] -= 160

dolphin_path = Path(vertices, codes)
dolphin_patch = PathPatch(dolphin_path, facecolor=(0.6, 0.6, 0.6),
                          edgecolor=(0.0, 0.0, 0.0))
ax.add_patch(dolphin_patch)

vertices = Affine2D().rotate_deg(60).transform(vertices)
dolphin_path2 = Path(vertices, codes)
dolphin_patch2 = PathPatch(dolphin_path2, facecolor=(0.5, 0.5, 0.5),
                           edgecolor=(0.0, 0.0, 0.0))
ax.add_patch(dolphin_patch2)
plt.title("I hope you like dolphins, {}".format(name))
plt.show()

# %% [markdown]
# ## So how does this magic happen?
#
# Google Colab is built on top of what is called Jupyter Notebook.<br>
# Jupyter Notebooks are documents produced by the Jupyter Notebook App, which contain both computer code (e.g. python) and rich text elements (paragraph, equations, figures, links, etc…). Notebook documents are both human-readable documents containing the analysis description and the results (figures, tables, etc..) as well as executable documents which can be run to perform data analysis. <br>
#
# While the Jupyter Notebook is a great step in the right direction when it comes to making coding easier, it still requires installing the server-client application and starting it on your machine. <br>
#
# Google Colab takes away this hassle by providing you with access to a virtual machine that has all these components installed.<br>
# You even have access to the linux running on this machine and can do pretty much whatever you want:

# %%
# let us print the list of directories on my virtual machine
# !ls -al /
# Out:
# total 8064
# drwxr-xr-x   1 root root    4096 Jun 12 14:26 .
# drwxr-xr-x   1 root root    4096 Jun 12 14:26 ..
# drwxr-xr-x   1 root root    4096 Jun 10 16:21 bin
# drwxr-xr-x   2 root root    4096 Apr 24  2018 boot
# drwxr-xr-x   1 root root    4096 Jun 10 16:28 content
# drwxr-xr-x   1 root root    4096 Jun 10 16:57 datalab
# drwxr-xr-x   5 root root     360 Jun 12 14:26 dev
# -rw-r--r--   1 root root 4078115 Jun 10 16:28 dlib-19.18.0-cp27-cp27mu-linux_x86_64.whl
# -rw-r--r--   1 root root 4068717 Jun 10 16:28 dlib-19.18.0-cp36-cp36m-linux_x86_64.whl
# -rwxr-xr-x   1 root root       0 Jun 12 14:26 .dockerenv
# drwxr-xr-x   1 root root    4096 Jun 12 14:26 etc
# drwxr-xr-x   2 root root    4096 Apr 24  2018 home
# drwxr-xr-x   1 root root    4096 Jun 10 16:22 lib
# drwxr-xr-x   2 root root    4096 Jun 10 16:16 lib32
# drwxr-xr-x   2 root root    4096 Oct 29  2019 lib64
# drwxr-xr-x   2 root root    4096 Oct 29  2019 media
# drwxr-xr-x   2 root root    4096 Oct 29  2019 mnt
# ...

# %%
# let's print the operating system
# !cat /etc/os-release
# Out:
# NAME="Ubuntu"
# VERSION="18.04.3 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.3 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic

# %% [markdown]
# ## Forms
#
# Forms provide an easy way to parameterize code. Think of it as some very basic user interface that gives your notebooks more personality. <br>
# From a code cell, select **Insert → Add form field**.  When you change the
# value in a form, the corresponding value in the code will change. <br>
# Once a cell has a form, you can click on the cell options (right hand side) and choose to hide the code.

# %%
#@markdown **Cats or dogs?**
animal = "Cat" #@param ["Cat", "Dog", "Platypus"] {allow-input: true}

#@markdown **How many do you have?**
number = 4 #@param {type:"slider", min:0, max:20, step:1}



print("It seems that {} is a {} person. {} are in their possession.".format(name, animal.lower(), number))
# Out:
# It seems that Raluca is a cat person. 6 are in his possession.

# %% [markdown]
# ## Let's do a quick mock up contract generator

# %%
#@markdown What is the customer name?
customer_name = "Olga"#@param (type:"string")
#@markdown What is the fee?

fee = "" #@param (type:"number")

Print = "My company and customer_name signed a contract for EUR fee"

# %% [markdown]
# ## So why not use Google Colab all the time?
#
# As nice and convenient as this tool is, there are a few drawbacks:
# - Is it mostly for testing things out
# - It is not a real application and can never be
# - Need to always be online
# - The cell structure and ability to run cells in any order can mess things up

# %% [markdown]
# ![alt text](https://miro.medium.com/max/1400/1*DFaRILoVj4jv0AAVb6EmDw.jpeg)

# %% [markdown]
# # Regular Expressions (or RegExp)
#
# ![Comic Time](https://imgs.xkcd.com/comics/regular_expressions.png)

# %% [markdown]
# ## What are RegExp?
# - As the comic above indicates, it’s a syntax for searching specific patterns in text (an address, URL, emails, numbers) <br>
# - It greatly simplifies the code that we could write using standard python string methods like split(), startswith(), endswith(), isalpha(), isdigit(), find()
# - They can become quite complex, entire books have been written about this subject. We will only cover the basics. https://en.wikipedia.org/wiki/Regular_expression
# - The power of the regular expressions comes when we add special characters to the search string that allow us to more precisely control which lines match the string. Adding these special characters to our regular expression allow us to do sophisticated matching and extraction while writing very little code.
# - They are not just Python specific, so other programming languages can have regex. Of course we will focus on the Python implementation

# %%
# here is the first code that deals with regex:
import re

text = "I want to search inside this text. This is just an example. Let's see if I can find the word: I"

found = re.search("I", text)
if found:
  print("I found the word 'I' on position ", found.start())
else: 
  print("I did not find 'I'")

found = re.search("We", text)
if found:
  print("I found the word 'We' on position ", found.start())
else: 
  print("I did not find 'We'")
# Out:
# I found the word 'I' on position  0
# I did not find 'We'

# %% [markdown]
# So this is the basic functionality: Find the first occurrence of the token inside the string.<br>
# The first steps were:
#
# 1.   Import re (re stands for regular expression and it is a standar library)
# 2.   Call the **search** function from the **re** library. This function takes 2 parameters: the regular expression to apply (the pattern to search) - in this first example it is just the letter 'I' and the second parameter is where to seach: in this example we have defined a simple text variable. Most of the times, you will want to search inside some external data source like a word file, pdf file, web page, etc.
# 3.   The function returns an object called a **Match Object**. If no match was found, the object is empty. We can use if to check if this object is empty or not. If it was found, this **match** object contains the information we care about like: at what position did the match occurred.
#
#
# This is somewhat useful, but we can improve.
# First improvement: let's find all the occurrences.

# %%
# here is the first code that deals with regex:
import re

text = "I want to search inside this text. This is just an example. Let's see if I can find the word: I"

found = re.finditer("I", text)
if found:
  print("I found the word 'I' {}  times".format(len(list(found))))
else: 
  print("I did not find 'I'")
# Out:
# I found the word 'I' 3  times

# %% [markdown]
# In order to find all occurrences we call the function **finditer**.<br>
# As the name suggests, it return an *iterator* object that has all the matches.<br>
# Think of an iterator object as a list of **Matched Objects**. So as all the lists, we can take each matched object and print useful information.<br>
# Let's combine the first 2 examples:

# %%
# here is the first code that deals with regex:
import re

text = "I want to search Inside this text. This is just an example. Let's see if I can find the word: I"

found = re.finditer("I", text)
if found:
  counter = 0
  for each_match in found:
    print("Occurence number {} of 'I' was on position {}".format(counter, each_match.start()))
    counter += 1

else: 
  print("I did not find 'I'")
# Out:
# Occurence number 0 of 'I' was on position 0
# Occurence number 1 of 'I' was on position 17
# Occurence number 2 of 'I' was on position 73
# Occurence number 3 of 'I' was on position 94

# %% [markdown]
# Let's take it a step further: <br>
# RegEx would not be so useful if we could only search for static tokens (a text that can only have one meaning). <br>
# RegEx allows us to define patterns such as:
# - an email address
# - a date
# - a telephone number
# - a valid card number
#
# So they are used as both a way to search for information, but also to validate input. Think of a website that asks for your email address. How does it know if **bratiu@ie.edu** is valid, but **bratiu-ie.edu** is no valid? The answer is of course RegEx :)

# %% [markdown]
# ##Metacharacters and Forming Patterns
# Some characters, like '|' or '(', are special. Special characters either stand for classes of ordinary characters, or affect how the regular expressions around them are interpreted.<br>
# Here are the most common pattern conventions:
# - **a, X, 9, <** -- ordinary characters just match themselves exactly. The meta-characters which do not match themselves because they have special meanings are: . ^ $ * + ? { [ ] \ | ( )
#
# - **.** (a period) -- matches any single character except newline **'\n'**
#
# - **\w** -- (lowercase w) matches a "word" character: a letter or digit or underbar [a-zA-Z0-9_].
# - **\b** -- boundary between word and non-word
# - **\t, \n, \r** -- tab, newline, return
# - **^** = start, **$** = end -- match the start or end of the string
# - **\** -- inhibit the "specialness" of a character. So, for example, use \\. to match a period or \\\ to match a slash.
#
# Another set of conventions are the repetitions:
# - **\+** -- 1 or more occurrences of the pattern to its left, e.g. 'i+' = one or more i's
# - **\*** -- 0 or more occurrences of the pattern to its left
# - **?** -- match 0 or 1 occurrences of the pattern to its left
# - **{x}** – match x occurrences of the pattern to its left
# - **{x,y}** – match between x and y occurrences of the pattern to its left

# %%
# here are some examples:
## i+ = one or more i's, as many as possible.

#1
match = re.search(r'pi+', 'piiig') # found, match.group() == "piii"
print(1, match.group())

#2
match = re.search(r'i+', 'piigiiii') # found, match.group() == "ii", just the first one!
print(2, match.group())

#2-bis
match = list(re.finditer(r'i+', 'piigiiii')) # found, match.group() == "ii", just the first one!
print("2-bis", match[1].group()) # second match


#3
## ^ = matches the start of string, so this fails:
match = re.search(r'^bar', 'foobar') # not found, match == None
print(3, match)

#4
## but without the ^ it succeeds:
match = re.search(r'b\w+', 'foobar') # found, match.group() == "bar“
print(4, match.group())

#5
match = re.search(r'(pig){2}', 'i have a pig and a pigpig') # found, match.group() == "pigpig"
print(5, match.group())

#6
match = re.search(r'\bpig\b', 'i have a pig and a pigpig') # found, match.group() == "pig"
print(6, match.group())

#7
match = re.search(r'.*', 'i have a pig and a pigpig') # this one matches all the string on a line
print(7, match.group())
# Out:
# 1 piii
# 2 ii
# 2-bis iiii
# 3 None
# 4 bar
# 5 pigpig
# 6 pig
# 7 i have a pig and a pigpig

# %% [markdown]
# ## Grouping into sets
# The last improvement we want to talk about are **[]**: <br>
# - They are used to indicate a set of chars, so **[abc]** matches 'a' or 'b' or 'c'. <br>
# - You can use **–** to indicate a sequence of characters **[a-z]** – all the lowercase characters <br>
# - Special characters lose their special meaning inside sets. For example, [(+*)] will match any of the literal characters '(', '+', '*', or ')'.
#
# - Characters that are not within a range can be matched by complementing the set. If the first character of the set is '^', all the characters that are not in the set will be matched. For example, [^5] will match any character except '5', and [^^] will match any character except '^'. ^ has no special meaning if it’s not the first character in the set.
#
# - To match a literal ']' inside a set, precede it with a backslash, or place it at the beginning of the set. For example, both [()[\]{}] and []()[{}] will both match a parenthesis.
# - Repetition symbols can be used after a set.
#
# **findall** is a simpler case of **finditer**. It just returns a list of all the matches. Sometimes it is all that we need.<br>

# %% [markdown]
# ## Examples

# %%
text = "I want to search Inside this text. This is just an example. Let's see if I can find the word: I. My name is Bogdan Ratiu and I like to teach spectacular things"

#let's find all the 4 letter words:
words = re.findall(r"\b[\w]{4}\b", text)
print(words)

# what is we omit the \b ? 
words = re.findall(r"[\w]{4}", text)
print("without the \b we have: ", words)

# let us find all the proper names. A proper name is a collection of 2 words starting with a capital letter and with a space betweeen
names = re.findall(r"\b[A-Z]\w+ [A-Z]\w+\b", text)
print("Proper names:", names)

# match any number between 0-255
text = "122 345 1234 098 23 7 99 553"
expr = r"\b([0-9]|[1-9][0-9]|1[0-9][0-9]|2[0-4][0-9]|25[0-5])\b"
matched = re.findall(expr, text)
print("The numbers in the range 0-255 are", matched)
# Out:
# ['want', 'this', 'text', 'This', 'just', 'find', 'word', 'name', 'like']
#  we have:  ['want', 'sear', 'Insi', 'this', 'text', 'This', 'just', 'exam', 'find', 'word', 'name', 'Bogd', 'Rati', 'like', 'teac', 'spec', 'tacu', 'thin']
# Proper names: ['Bogdan Ratiu']
# The numbers in the range 0-255 are ['122', '23', '7', '99']

# %% [markdown]
# ## Find the email addresses inside a word document

# %%
# !pip install python-docx

# %%
import re
import docx
from urllib.request import urlretrieve

#make sure that email contain @ and . after and there are no spaces in the middle
#classic way of getting the emails, without regex, quite complicated and not as good
def find_emails_classic(str):
    start = 0
    poz_start = 0
    emails_list = []
    while True:
        poz_at = str.find("@", start)
        if poz_at == -1:
            break

        poz_point = 0
        while poz_point < poz_at:
            poz_point = str.find(".", poz_point + 1)
            if poz_point == -1:
                break

        tmp = str.find(" ", start)
        while tmp < poz_at:
            poz_start = tmp + 1
            tmp = str.find(" ", poz_start)
            if tmp == -1:
                break

        #discard fake emails with spaces like: aaa@bbb ccc.dd
        poz_end = str.find(" ", poz_at)
        if poz_end < poz_point and poz_end != -1:
            start = poz_end
            continue

        poz_end = str.find(" ", poz_point)

        if poz_end == -1:
            emails_list.append(str[poz_start:])
        else:
            emails_list.append(str[poz_start: poz_end])

        start = poz_end
    return emails_list

#find emails via regex. Notice how much simpler it is:
reg_exp = "[a-zA-Z0-9]+@[a-zA-Z0-9]+\.[a-zA-Z0-9]+"
def find_emails_regex(str):
    return re.findall(reg_exp, str)

#make sure you have the right path to the DOCX file! We use urlretrieve
path = "https://github.com/itb-ie/MasterLaw-Session1-2/raw/master/Merger%20Agreement.docx"
filename2 = "emails.docx"
urlretrieve(path, "contract.docx")
doc = docx.Document("contract.docx")

all_emails = []
for para in doc.paragraphs:
    list_emails = find_emails_regex(para.text)
    for email in list_emails:
        all_emails.append(email)

#we have the emails
print("we now print the all_emails")
print(all_emails)
print("we are done")

doc = docx.Document()
para = doc.add_paragraph()
for em in all_emails:
    run = para.add_run(em)
    run.add_break()

doc.save(filename2)

# %% [markdown]
# #Q&A
# ![Q&A](https://github.com/itb-ie/MasterLaw-Session1-2/raw/master/q%26a.png)
